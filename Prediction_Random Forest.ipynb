# %%
# Basic Libraries
from collections import Counter
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import os

#Preprocessing
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from imblearn.pipeline import Pipeline

#Classifier
from sklearn.ensemble import RandomForestRegressor

#Evaluation
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold 

from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score,roc_auc_score
from sklearn.model_selection import cross_validate

# %%
# Read Dataset
folder_path = 'C:/Users/Mahin Vazifehdan/Desktop/Datasets/Imputed_dataset/'
list_path = os.listdir(folder_path)
for i in range(len(list_path)):
    data = pd.read_csv(folder_path + list_path[i])
    # Drop target from dataset for prediction
    target = data["EDSS_score_assessed_by_clinician"]
    data = data.drop(columns = ['EDSS_score_assessed_by_clinician'], axis = 1)
    data = data.drop(columns = ['Date_of_visit'], axis = 1)
    # We define our candiate values
    Tree_numbers = np.arange(100, 350, 50)
    cross_val_scores = []

    X_trainval, X_test, y_trainval, y_test = train_test_split(data, target , random_state=42,test_size = 0.2)

    for t in Tree_numbers:
        # We define the model with hyper-parameters
        Random_Forest = RandomForestRegressor(n_estimators=t, max_depth=7, random_state=0)
        scaler= MinMaxScaler()
        steps = [("scaler", scaler), ('regression', Random_Forest)]
        pipeline = Pipeline(steps=steps)

        # Fitting 10 models, and returning 10 scores
        scores = cross_val_score(pipeline ,X_trainval, y_trainval, cv=10)
        # We record the average score over the 10 folds
        cross_val_scores.append(np.mean(scores))
        # We can compute the best mean score
        print("dataset:" + list_path[i].split(".")[0])
        print(f"best cross-validation score: {np.max(cross_val_scores):.3}")
        # and corresponding best parameters
        best_n_tree = Tree_numbers[np.argmax(cross_val_scores)]
        print(f"best n_tree: {best_n_tree}")
        Random_Forest = RandomForestRegressor(n_estimators=best_n_tree)
        Random_Forest.fit(X_trainval, y_trainval)
        print(f"test-set score: {Random_Forest.score(X_test, y_test):.3f}")
        print("*"*50)
# Out:
# dataset:imputed_data_cart
# best cross-validation score: 0.838
# best n_tree: 100
# test-set score: 0.931
# **************************************************
# dataset:imputed_data_cart
# best cross-validation score: 0.839
# best n_tree: 150
# test-set score: 0.932
# **************************************************
# dataset:imputed_data_cart
# best cross-validation score: 0.839
# best n_tree: 200
# test-set score: 0.932
# **************************************************
# dataset:imputed_data_cart
# best cross-validation score: 0.839
# best n_tree: 250
# test-set score: 0.932
# **************************************************
# dataset:imputed_data_cart
# best cross-validation score: 0.839
# best n_tree: 300
# test-set score: 0.933
# **************************************************
# dataset:imputed_data_continuous
# best cross-validation score: 0.827
# best n_tree: 100
# test-set score: 0.922
# **************************************************
# dataset:imputed_data_continuous
# best cross-validation score: 0.827
# best n_tree: 150
# test-set score: 0.921
# **************************************************
# dataset:imputed_data_continuous
# best cross-validation score: 0.827
# best n_tree: 150
# test-set score: 0.922
# **************************************************
# dataset:imputed_data_continuous
# best cross-validation score: 0.827
# best n_tree: 250
# test-set score: 0.923
# **************************************************
# dataset:imputed_data_continuous
# best cross-validation score: 0.827
# best n_tree: 300
# test-set score: 0.922
# **************************************************
# dataset:imputed_data_EWMA
# best cross-validation score: 0.722
# best n_tree: 100
# test-set score: 0.875
# **************************************************
# dataset:imputed_data_EWMA
# best cross-validation score: 0.722
# best n_tree: 100
# test-set score: 0.875
# **************************************************
# dataset:imputed_data_EWMA
# best cross-validation score: 0.722
# best n_tree: 200
# test-set score: 0.872
# **************************************************
# dataset:imputed_data_EWMA
# best cross-validation score: 0.722
# best n_tree: 200
# test-set score: 0.876
# **************************************************
# dataset:imputed_data_EWMA
# best cross-validation score: 0.722
# best n_tree: 300
# test-set score: 0.876
# **************************************************
# dataset:imputed_data_linear
# best cross-validation score: 0.732
# best n_tree: 100
# test-set score: 0.884
# **************************************************
# dataset:imputed_data_linear
# best cross-validation score: 0.732
# best n_tree: 150
# test-set score: 0.884
# **************************************************
# dataset:imputed_data_linear
# best cross-validation score: 0.732
# best n_tree: 150
# test-set score: 0.883
# **************************************************
# dataset:imputed_data_linear
# best cross-validation score: 0.732
# best n_tree: 150
# test-set score: 0.884
# **************************************************
# dataset:imputed_data_linear
# best cross-validation score: 0.732
# best n_tree: 150
# test-set score: 0.885
# **************************************************
# dataset:imputed_data_rf
# best cross-validation score: 0.819
# best n_tree: 100
# test-set score: 0.913
# **************************************************
# dataset:imputed_data_rf
# best cross-validation score: 0.819
# best n_tree: 100
# test-set score: 0.913
# **************************************************
# dataset:imputed_data_rf
# best cross-validation score: 0.82
# best n_tree: 200
# test-set score: 0.913
# **************************************************
# dataset:imputed_data_rf
# best cross-validation score: 0.82
# best n_tree: 200
# test-set score: 0.913
# **************************************************
# dataset:imputed_data_rf
# best cross-validation score: 0.82
# best n_tree: 200
# test-set score: 0.913
# **************************************************
